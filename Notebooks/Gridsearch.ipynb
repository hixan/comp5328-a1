# %%
from collections import namedtuple
from NMF_Implementation.L21Norm import Algorithm as L21Norm
from NMF_Implementation.L2Norm import Algorithm as L2Norm
from NMF_Implementation.base import load_data, Implementation
from NMF_Implementation.Noise import salt_and_pepper
import numpy as np
from typing import Dict
OUTPUT_FILENAME = 'gridsearch/gridsearch.csv'
OUTPUT_LOSS_PREFIX = 'losses/loss'
OUTPUT_RESIDUE_PREFIX = 'losses/residue'

observation = namedtuple('Observation', ['p', 'r', 'k', 'modeltype', 'dataset'])

ordered_grid = []
for dataset in 'orl', 'yale':
    for r in 0.5, 0.2, 0.8:
        for p in 0.1, 0.2, 0.4:
            for k in 1, 10, 100:
                for modeltype in 'l21', 'l2':
                    ordered_grid.append(observation(
                        p=p, r=r, k=k, modeltype=modeltype,
                        dataset=dataset
                    ))
for dataset in 'orl', 'yale':
    for r in 0.5, 0.2, 0.8:
        for p in 0.1, 0.2, 0.4:
            for k in 20, 200, 500:
                for modeltype in 'l21', 'l2':
                    ordered_grid.append(observation(
                        p=p, r=r, k=k, modeltype=modeltype,
                        dataset=dataset
                    ))
for dataset in 'orl', 'yale':
    for r in 0.5, 0.2, 0.8:
        for p in 0.1, 0.2, 0.4:
            for k in [1000]:
                for modeltype in ['l21', 'l2']:
                    ordered_grid.append(observation(
                        p=p, r=r, k=k, modeltype=modeltype,
                        dataset=dataset
                    ))

# %%
Xo, Yo = load_data('../data/ORL', (30, 37))
Xy, Yy = load_data('../data/CroppedYaleB', (30, 37))
Xo = Xo
Xy = Xy

model_classes : Dict[str, Implementation] = dict(
    l21=L21Norm,
    l2=L2Norm
)
datasets = dict(
    orl=Xo,
    yale=Xy,
)

# %%
#with open(OUTPUT_FILENAME, 'w') as f: print('components,proportion_noise,ratio_white,dataset,model_type,result_filenumber,reconstruction_error,train_time', file=f) 
lossnum = 1000
def run_model(obs_param):
    global lossnum
    # unpack tuple
    k = obs_param.k
    p = obs_param.p
    r = obs_param.r
    ds = obs_param.dataset
    md = obs_param.modeltype
    
    if ds == 'orl' and True:  # skip orls
        lossnum += 1
        return
    
    dataset = datasets[ds]
    
    # create model
    model = model_classes[md](k, stop_threshold=-np.inf, max_iter=1000)
    
    def noise(X):
        return salt_and_pepper(X, p, r)

    # generate noisy data
    noisy = noise(dataset)
    
    # train model with noisy data
    start_t = datetime.now()
    model.fit(noisy)
    time_taken = (datetime.now() - start_t).total_seconds()
    
    # extract loss and residue
    loss = model.get_metavalues()['training_loss']
    residue = model.get_metavalues()['training_residue']
    
    reconstruction_error = model.reconstruction_error(noisy, dataset)
    
    # save the data!
    # save reconstruction error
    with open(OUTPUT_FILENAME, 'a') as f:
        print(f'{k},{p},{r},{ds},{md},{lossnum},{reconstruction_error},{time_taken}', file=f)
    # save losses
    with open(f'{OUTPUT_LOSS_PREFIX}{lossnum}.csv', 'w') as f:
        print(*loss, sep=',\n', end='', file=f)
    # save residues
    with open(f'{OUTPUT_RESIDUE_PREFIX}{lossnum}.csv', 'w') as f:
        print(*loss, sep=',\n', end='', file=f)
    lossnum += 1
    return time_taken
    
from datetime import datetime
for i, obs in enumerate(ordered_grid):
    print(f'running {obs}. {lossnum} / {len(ordered_grid)} ({lossnum / len(ordered_grid):.2f}%) ', end='')
    time_taken = run_model(obs)
    print(f'{time_taken}s')
# Out:
# running Observation(p=0.1, r=0.5, k=1, modeltype='l21', dataset='orl'). 1000 / 252 (3.97%) Nones
# running Observation(p=0.1, r=0.5, k=1, modeltype='l2', dataset='orl'). 1001 / 252 (3.97%) Nones
# running Observation(p=0.1, r=0.5, k=10, modeltype='l21', dataset='orl'). 1002 / 252 (3.98%) Nones
# running Observation(p=0.1, r=0.5, k=10, modeltype='l2', dataset='orl'). 1003 / 252 (3.98%) Nones
# running Observation(p=0.1, r=0.5, k=100, modeltype='l21', dataset='orl'). 1004 / 252 (3.98%) Nones
# running Observation(p=0.1, r=0.5, k=100, modeltype='l2', dataset='orl'). 1005 / 252 (3.99%) Nones
# running Observation(p=0.2, r=0.5, k=1, modeltype='l21', dataset='orl'). 1006 / 252 (3.99%) Nones
# running Observation(p=0.2, r=0.5, k=1, modeltype='l2', dataset='orl'). 1007 / 252 (4.00%) Nones
# running Observation(p=0.2, r=0.5, k=10, modeltype='l21', dataset='orl'). 1008 / 252 (4.00%) Nones
# running Observation(p=0.2, r=0.5, k=10, modeltype='l2', dataset='orl'). 1009 / 252 (4.00%) Nones
# running Observation(p=0.2, r=0.5, k=100, modeltype='l21', dataset='orl'). 1010 / 252 (4.01%) Nones
# running Observation(p=0.2, r=0.5, k=100, modeltype='l2', dataset='orl'). 1011 / 252 (4.01%) Nones
# running Observation(p=0.4, r=0.5, k=1, modeltype='l21', dataset='orl'). 1012 / 252 (4.02%) Nones
# running Observation(p=0.4, r=0.5, k=1, modeltype='l2', dataset='orl'). 1013 / 252 (4.02%) Nones
# running Observation(p=0.4, r=0.5, k=10, modeltype='l21', dataset='orl'). 1014 / 252 (4.02%) Nones
# running Observation(p=0.4, r=0.5, k=10, modeltype='l2', dataset='orl'). 1015 / 252 (4.03%) Nones
# running Observation(p=0.4, r=0.5, k=100, modeltype='l21', dataset='orl'). 1016 / 252 (4.03%) Nones
# running Observation(p=0.4, r=0.5, k=100, modeltype='l2', dataset='orl'). 1017 / 252 (4.04%) Nones
# running Observation(p=0.1, r=0.2, k=1, modeltype='l21', dataset='orl'). 1018 / 252 (4.04%) Nones
# running Observation(p=0.1, r=0.2, k=1, modeltype='l2', dataset='orl'). 1019 / 252 (4.04%) Nones
# running Observation(p=0.1, r=0.2, k=10, modeltype='l21', dataset='orl'). 1020 / 252 (4.05%) Nones
# running Observation(p=0.1, r=0.2, k=10, modeltype='l2', dataset='orl'). 1021 / 252 (4.05%) Nones
# running Observation(p=0.1, r=0.2, k=100, modeltype='l21', dataset='orl'). 1022 / 252 (4.06%) Nones
# running Observation(p=0.1, r=0.2, k=100, modeltype='l2', dataset='orl'). 1023 / 252 (4.06%) Nones
# running Observation(p=0.2, r=0.2, k=1, modeltype='l21', dataset='orl'). 1024 / 252 (4.06%) Nones
# running Observation(p=0.2, r=0.2, k=1, modeltype='l2', dataset='orl'). 1025 / 252 (4.07%) Nones
# running Observation(p=0.2, r=0.2, k=10, modeltype='l21', dataset='orl'). 1026 / 252 (4.07%) Nones
# running Observation(p=0.2, r=0.2, k=10, modeltype='l2', dataset='orl'). 1027 / 252 (4.08%) Nones
# running Observation(p=0.2, r=0.2, k=100, modeltype='l21', dataset='orl'). 1028 / 252 (4.08%) Nones
# running Observation(p=0.2, r=0.2, k=100, modeltype='l2', dataset='orl'). 1029 / 252 (4.08%) Nones
# running Observation(p=0.4, r=0.2, k=1, modeltype='l21', dataset='orl'). 1030 / 252 (4.09%) Nones
# running Observation(p=0.4, r=0.2, k=1, modeltype='l2', dataset='orl'). 1031 / 252 (4.09%) Nones
# running Observation(p=0.4, r=0.2, k=10, modeltype='l21', dataset='orl'). 1032 / 252 (4.10%) Nones
# running Observation(p=0.4, r=0.2, k=10, modeltype='l2', dataset='orl'). 1033 / 252 (4.10%) Nones
# running Observation(p=0.4, r=0.2, k=100, modeltype='l21', dataset='orl'). 1034 / 252 (4.10%) Nones
# running Observation(p=0.4, r=0.2, k=100, modeltype='l2', dataset='orl'). 1035 / 252 (4.11%) Nones
# running Observation(p=0.1, r=0.8, k=1, modeltype='l21', dataset='orl'). 1036 / 252 (4.11%) Nones
# running Observation(p=0.1, r=0.8, k=1, modeltype='l2', dataset='orl'). 1037 / 252 (4.12%) Nones
# running Observation(p=0.1, r=0.8, k=10, modeltype='l21', dataset='orl'). 1038 / 252 (4.12%) Nones
# running Observation(p=0.1, r=0.8, k=10, modeltype='l2', dataset='orl'). 1039 / 252 (4.12%) Nones
# running Observation(p=0.1, r=0.8, k=100, modeltype='l21', dataset='orl'). 1040 / 252 (4.13%) Nones
# running Observation(p=0.1, r=0.8, k=100, modeltype='l2', dataset='orl'). 1041 / 252 (4.13%) Nones
# running Observation(p=0.2, r=0.8, k=1, modeltype='l21', dataset='orl'). 1042 / 252 (4.13%) Nones
# running Observation(p=0.2, r=0.8, k=1, modeltype='l2', dataset='orl'). 1043 / 252 (4.14%) Nones
# running Observation(p=0.2, r=0.8, k=10, modeltype='l21', dataset='orl'). 1044 / 252 (4.14%) Nones
# running Observation(p=0.2, r=0.8, k=10, modeltype='l2', dataset='orl'). 1045 / 252 (4.15%) Nones
# running Observation(p=0.2, r=0.8, k=100, modeltype='l21', dataset='orl'). 1046 / 252 (4.15%) Nones
# running Observation(p=0.2, r=0.8, k=100, modeltype='l2', dataset='orl'). 1047 / 252 (4.15%) Nones
# running Observation(p=0.4, r=0.8, k=1, modeltype='l21', dataset='orl'). 1048 / 252 (4.16%) Nones
# running Observation(p=0.4, r=0.8, k=1, modeltype='l2', dataset='orl'). 1049 / 252 (4.16%) Nones
# running Observation(p=0.4, r=0.8, k=10, modeltype='l21', dataset='orl'). 1050 / 252 (4.17%) Nones
# running Observation(p=0.4, r=0.8, k=10, modeltype='l2', dataset='orl'). 1051 / 252 (4.17%) Nones
# running Observation(p=0.4, r=0.8, k=100, modeltype='l21', dataset='orl'). 1052 / 252 (4.17%) Nones
# running Observation(p=0.4, r=0.8, k=100, modeltype='l2', dataset='orl'). 1053 / 252 (4.18%) Nones
# running Observation(p=0.1, r=0.5, k=1, modeltype='l21', dataset='yale'). 1054 / 252 (4.18%) 96.28327s
# running Observation(p=0.1, r=0.5, k=1, modeltype='l2', dataset='yale'). 1055 / 252 (4.19%) 66.905456s
# running Observation(p=0.1, r=0.5, k=10, modeltype='l21', dataset='yale'). 1056 / 252 (4.19%) 101.867037s
# running Observation(p=0.1, r=0.5, k=10, modeltype='l2', dataset='yale'). 1057 / 252 (4.19%) 64.373841s
# running Observation(p=0.1, r=0.5, k=100, modeltype='l21', dataset='yale'). 1058 / 252 (4.20%) 152.363862s
# running Observation(p=0.1, r=0.5, k=100, modeltype='l2', dataset='yale'). 1059 / 252 (4.20%) 79.047218s
# running Observation(p=0.2, r=0.5, k=1, modeltype='l21', dataset='yale'). 1060 / 252 (4.21%) 99.317583s
# running Observation(p=0.2, r=0.5, k=1, modeltype='l2', dataset='yale'). 1061 / 252 (4.21%) 70.327501s
# running Observation(p=0.2, r=0.5, k=10, modeltype='l21', dataset='yale'). 1062 / 252 (4.21%) 100.272816s
# running Observation(p=0.2, r=0.5, k=10, modeltype='l2', dataset='yale'). 1063 / 252 (4.22%) 61.421892s
# running Observation(p=0.2, r=0.5, k=100, modeltype='l21', dataset='yale'). 1064 / 252 (4.22%) 161.582752s
# running Observation(p=0.2, r=0.5, k=100, modeltype='l2', dataset='yale'). 1065 / 252 (4.23%) 82.819588s
# running Observation(p=0.4, r=0.5, k=1, modeltype='l21', dataset='yale'). 1066 / 252 (4.23%) 102.214124s
# running Observation(p=0.4, r=0.5, k=1, modeltype='l2', dataset='yale'). 1067 / 252 (4.23%) 69.496408s
# running Observation(p=0.4, r=0.5, k=10, modeltype='l21', dataset='yale'). 1068 / 252 (4.24%) 106.153174s
# running Observation(p=0.4, r=0.5, k=10, modeltype='l2', dataset='yale'). 1069 / 252 (4.24%) 65.926899s
# running Observation(p=0.4, r=0.5, k=100, modeltype='l21', dataset='yale'). 1070 / 252 (4.25%) 155.932469s
# running Observation(p=0.4, r=0.5, k=100, modeltype='l2', dataset='yale'). 1071 / 252 (4.25%) 80.15907s
# running Observation(p=0.1, r=0.2, k=1, modeltype='l21', dataset='yale'). 1072 / 252 (4.25%) 100.110378s
# running Observation(p=0.1, r=0.2, k=1, modeltype='l2', dataset='yale'). 1073 / 252 (4.26%) 72.968321s
# running Observation(p=0.1, r=0.2, k=10, modeltype='l21', dataset='yale'). 1074 / 252 (4.26%) 106.452256s
# running Observation(p=0.1, r=0.2, k=10, modeltype='l2', dataset='yale'). 1075 / 252 (4.27%) 67.211205s
# running Observation(p=0.1, r=0.2, k=100, modeltype='l21', dataset='yale'). 1076 / 252 (4.27%) 155.208871s
# running Observation(p=0.1, r=0.2, k=100, modeltype='l2', dataset='yale'). 1077 / 252 (4.27%) 77.635641s
# running Observation(p=0.2, r=0.2, k=1, modeltype='l21', dataset='yale'). 1078 / 252 (4.28%) 97.389196s
# running Observation(p=0.2, r=0.2, k=1, modeltype='l2', dataset='yale'). 1079 / 252 (4.28%) 70.811512s
# running Observation(p=0.2, r=0.2, k=10, modeltype='l21', dataset='yale'). 1080 / 252 (4.29%) 103.825483s
# running Observation(p=0.2, r=0.2, k=10, modeltype='l2', dataset='yale'). 1081 / 252 (4.29%) 64.23135s
# running Observation(p=0.2, r=0.2, k=100, modeltype='l21', dataset='yale'). 1082 / 252 (4.29%) 150.950153s
# running Observation(p=0.2, r=0.2, k=100, modeltype='l2', dataset='yale'). 1083 / 252 (4.30%) 82.926923s
# running Observation(p=0.4, r=0.2, k=1, modeltype='l21', dataset='yale'). 1084 / 252 (4.30%) 100.729892s
# running Observation(p=0.4, r=0.2, k=1, modeltype='l2', dataset='yale'). 1085 / 252 (4.31%) 71.219069s
# running Observation(p=0.4, r=0.2, k=10, modeltype='l21', dataset='yale'). 1086 / 252 (4.31%) 105.781389s
# running Observation(p=0.4, r=0.2, k=10, modeltype='l2', dataset='yale'). 1087 / 252 (4.31%) 61.784406s
# running Observation(p=0.4, r=0.2, k=100, modeltype='l21', dataset='yale'). 1088 / 252 (4.32%) 154.330884s
# running Observation(p=0.4, r=0.2, k=100, modeltype='l2', dataset='yale'). 1089 / 252 (4.32%) 93.898413s
# running Observation(p=0.1, r=0.8, k=1, modeltype='l21', dataset='yale'). 1090 / 252 (4.33%) 120.759727s
# running Observation(p=0.1, r=0.8, k=1, modeltype='l2', dataset='yale'). 1091 / 252 (4.33%) 72.2643s
# running Observation(p=0.1, r=0.8, k=10, modeltype='l21', dataset='yale'). 1092 / 252 (4.33%) 104.129269s
# running Observation(p=0.1, r=0.8, k=10, modeltype='l2', dataset='yale'). 1093 / 252 (4.34%) 65.765264s
# running Observation(p=0.1, r=0.8, k=100, modeltype='l21', dataset='yale'). 1094 / 252 (4.34%) 157.155159s
# running Observation(p=0.1, r=0.8, k=100, modeltype='l2', dataset='yale'). 1095 / 252 (4.35%) 81.834881s
# running Observation(p=0.2, r=0.8, k=1, modeltype='l21', dataset='yale'). 1096 / 252 (4.35%) 104.646911s
# running Observation(p=0.2, r=0.8, k=1, modeltype='l2', dataset='yale'). 1097 / 252 (4.35%) 71.267292s
# running Observation(p=0.2, r=0.8, k=10, modeltype='l21', dataset='yale'). 1098 / 252 (4.36%) 103.73905s
# running Observation(p=0.2, r=0.8, k=10, modeltype='l2', dataset='yale'). 1099 / 252 (4.36%) 67.034246s
# running Observation(p=0.2, r=0.8, k=100, modeltype='l21', dataset='yale'). 1100 / 252 (4.37%) 233.887807s
# running Observation(p=0.2, r=0.8, k=100, modeltype='l2', dataset='yale'). 1101 / 252 (4.37%) 149.284572s
# running Observation(p=0.4, r=0.8, k=1, modeltype='l21', dataset='yale'). 1102 / 252 (4.37%) 199.426509s
# running Observation(p=0.4, r=0.8, k=1, modeltype='l2', dataset='yale'). 1103 / 252 (4.38%) 135.287029s
# running Observation(p=0.4, r=0.8, k=10, modeltype='l21', dataset='yale'). 1104 / 252 (4.38%) 210.299164s
# running Observation(p=0.4, r=0.8, k=10, modeltype='l2', dataset='yale'). 1105 / 252 (4.38%) 123.589463s
# running Observation(p=0.4, r=0.8, k=100, modeltype='l21', dataset='yale'). 1106 / 252 (4.39%) 350.741534s
# running Observation(p=0.4, r=0.8, k=100, modeltype='l2', dataset='yale'). 1107 / 252 (4.39%) 160.526388s
# running Observation(p=0.1, r=0.5, k=20, modeltype='l21', dataset='orl'). 1108 / 252 (4.40%) Nones
# running Observation(p=0.1, r=0.5, k=20, modeltype='l2', dataset='orl'). 1109 / 252 (4.40%) Nones
# running Observation(p=0.1, r=0.5, k=200, modeltype='l21', dataset='orl'). 1110 / 252 (4.40%) Nones
# running Observation(p=0.1, r=0.5, k=200, modeltype='l2', dataset='orl'). 1111 / 252 (4.41%) Nones
# running Observation(p=0.1, r=0.5, k=500, modeltype='l21', dataset='orl'). 1112 / 252 (4.41%) Nones
# running Observation(p=0.1, r=0.5, k=500, modeltype='l2', dataset='orl'). 1113 / 252 (4.42%) Nones
# running Observation(p=0.2, r=0.5, k=20, modeltype='l21', dataset='orl'). 1114 / 252 (4.42%) Nones
# running Observation(p=0.2, r=0.5, k=20, modeltype='l2', dataset='orl'). 1115 / 252 (4.42%) Nones
# running Observation(p=0.2, r=0.5, k=200, modeltype='l21', dataset='orl'). 1116 / 252 (4.43%) Nones
# running Observation(p=0.2, r=0.5, k=200, modeltype='l2', dataset='orl'). 1117 / 252 (4.43%) Nones
# running Observation(p=0.2, r=0.5, k=500, modeltype='l21', dataset='orl'). 1118 / 252 (4.44%) Nones
# running Observation(p=0.2, r=0.5, k=500, modeltype='l2', dataset='orl'). 1119 / 252 (4.44%) Nones
# running Observation(p=0.4, r=0.5, k=20, modeltype='l21', dataset='orl'). 1120 / 252 (4.44%) Nones
# running Observation(p=0.4, r=0.5, k=20, modeltype='l2', dataset='orl'). 1121 / 252 (4.45%) Nones
# running Observation(p=0.4, r=0.5, k=200, modeltype='l21', dataset='orl'). 1122 / 252 (4.45%) Nones
# running Observation(p=0.4, r=0.5, k=200, modeltype='l2', dataset='orl'). 1123 / 252 (4.46%) Nones
# running Observation(p=0.4, r=0.5, k=500, modeltype='l21', dataset='orl'). 1124 / 252 (4.46%) Nones
# running Observation(p=0.4, r=0.5, k=500, modeltype='l2', dataset='orl'). 1125 / 252 (4.46%) Nones
# running Observation(p=0.1, r=0.2, k=20, modeltype='l21', dataset='orl'). 1126 / 252 (4.47%) Nones
# running Observation(p=0.1, r=0.2, k=20, modeltype='l2', dataset='orl'). 1127 / 252 (4.47%) Nones
# running Observation(p=0.1, r=0.2, k=200, modeltype='l21', dataset='orl'). 1128 / 252 (4.48%) Nones
# running Observation(p=0.1, r=0.2, k=200, modeltype='l2', dataset='orl'). 1129 / 252 (4.48%) Nones
# running Observation(p=0.1, r=0.2, k=500, modeltype='l21', dataset='orl'). 1130 / 252 (4.48%) Nones
# running Observation(p=0.1, r=0.2, k=500, modeltype='l2', dataset='orl'). 1131 / 252 (4.49%) Nones
# running Observation(p=0.2, r=0.2, k=20, modeltype='l21', dataset='orl'). 1132 / 252 (4.49%) Nones
# running Observation(p=0.2, r=0.2, k=20, modeltype='l2', dataset='orl'). 1133 / 252 (4.50%) Nones
# running Observation(p=0.2, r=0.2, k=200, modeltype='l21', dataset='orl'). 1134 / 252 (4.50%) Nones
# running Observation(p=0.2, r=0.2, k=200, modeltype='l2', dataset='orl'). 1135 / 252 (4.50%) Nones
# running Observation(p=0.2, r=0.2, k=500, modeltype='l21', dataset='orl'). 1136 / 252 (4.51%) Nones
# running Observation(p=0.2, r=0.2, k=500, modeltype='l2', dataset='orl'). 1137 / 252 (4.51%) Nones
# running Observation(p=0.4, r=0.2, k=20, modeltype='l21', dataset='orl'). 1138 / 252 (4.52%) Nones
# running Observation(p=0.4, r=0.2, k=20, modeltype='l2', dataset='orl'). 1139 / 252 (4.52%) Nones
# running Observation(p=0.4, r=0.2, k=200, modeltype='l21', dataset='orl'). 1140 / 252 (4.52%) Nones
# running Observation(p=0.4, r=0.2, k=200, modeltype='l2', dataset='orl'). 1141 / 252 (4.53%) Nones
# running Observation(p=0.4, r=0.2, k=500, modeltype='l21', dataset='orl'). 1142 / 252 (4.53%) Nones
# running Observation(p=0.4, r=0.2, k=500, modeltype='l2', dataset='orl'). 1143 / 252 (4.54%) Nones
# running Observation(p=0.1, r=0.8, k=20, modeltype='l21', dataset='orl'). 1144 / 252 (4.54%) Nones
# running Observation(p=0.1, r=0.8, k=20, modeltype='l2', dataset='orl'). 1145 / 252 (4.54%) Nones
# running Observation(p=0.1, r=0.8, k=200, modeltype='l21', dataset='orl'). 1146 / 252 (4.55%) Nones
# running Observation(p=0.1, r=0.8, k=200, modeltype='l2', dataset='orl'). 1147 / 252 (4.55%) Nones
# running Observation(p=0.1, r=0.8, k=500, modeltype='l21', dataset='orl'). 1148 / 252 (4.56%) Nones
# running Observation(p=0.1, r=0.8, k=500, modeltype='l2', dataset='orl'). 1149 / 252 (4.56%) Nones
# running Observation(p=0.2, r=0.8, k=20, modeltype='l21', dataset='orl'). 1150 / 252 (4.56%) Nones
# running Observation(p=0.2, r=0.8, k=20, modeltype='l2', dataset='orl'). 1151 / 252 (4.57%) Nones
# running Observation(p=0.2, r=0.8, k=200, modeltype='l21', dataset='orl'). 1152 / 252 (4.57%) Nones
# running Observation(p=0.2, r=0.8, k=200, modeltype='l2', dataset='orl'). 1153 / 252 (4.58%) Nones
# running Observation(p=0.2, r=0.8, k=500, modeltype='l21', dataset='orl'). 1154 / 252 (4.58%) Nones
# running Observation(p=0.2, r=0.8, k=500, modeltype='l2', dataset='orl'). 1155 / 252 (4.58%) Nones
# running Observation(p=0.4, r=0.8, k=20, modeltype='l21', dataset='orl'). 1156 / 252 (4.59%) Nones
# running Observation(p=0.4, r=0.8, k=20, modeltype='l2', dataset='orl'). 1157 / 252 (4.59%) Nones
# running Observation(p=0.4, r=0.8, k=200, modeltype='l21', dataset='orl'). 1158 / 252 (4.60%) Nones
# running Observation(p=0.4, r=0.8, k=200, modeltype='l2', dataset='orl'). 1159 / 252 (4.60%) Nones
# running Observation(p=0.4, r=0.8, k=500, modeltype='l21', dataset='orl'). 1160 / 252 (4.60%) Nones
# running Observation(p=0.4, r=0.8, k=500, modeltype='l2', dataset='orl'). 1161 / 252 (4.61%) Nones
# running Observation(p=0.1, r=0.5, k=20, modeltype='l21', dataset='yale'). 1162 / 252 (4.61%) 149.410299s
# running Observation(p=0.1, r=0.5, k=20, modeltype='l2', dataset='yale'). 1163 / 252 (4.62%) 129.311839s
# running Observation(p=0.1, r=0.5, k=200, modeltype='l21', dataset='yale'). 1164 / 252 (4.62%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-8532d2318236> in <module>
#      52 for i, obs in enumerate(ordered_grid):
#      53     print(f'running {obs}. {lossnum} / {len(ordered_grid)} ({lossnum / len(ordered_grid):.2f}%) ', end='')
# ---> 54     time_taken = run_model(obs)
#      55     print(f'{time_taken}s')
#
# <ipython-input-20-8532d2318236> in run_model(obs_param)
#      27     # train model with noisy data
#      28     start_t = datetime.now()
# ---> 29     model.fit(noisy)
#      30     time_taken = (datetime.now() - start_t).total_seconds()
#      31
#
# ~/Documents/comp5328-a1/Notebooks/NMF_Implementation/L21Norm.py in fit(self, X, initial_representation)
#      87             if optim == 'D':
#      88                 optim = 'R'  # toggle for next time
# ---> 89                 D *= np.linalg.multi_dot((X, diag, R.T)) / np.linalg.multi_dot(
#      90                         (D, R, diag, R.T))
#      91             elif optim == 'R':
#
# <__array_function__ internals> in multi_dot(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/linalg/linalg.py in multi_dot(arrays, out)
#    2726     # _multi_dot_three is much faster than _multi_dot_matrix_chain_order
#    2727     if n == 3:
# -> 2728         result = _multi_dot_three(arrays[0], arrays[1], arrays[2], out=out)
#    2729     else:
#    2730         order = _multi_dot_matrix_chain_order(arrays)
#
# ~/.local/lib/python3.8/site-packages/numpy/linalg/linalg.py in _multi_dot_three(A, B, C, out)
#    2758         return dot(dot(A, B), C, out=out)
#    2759     else:
# -> 2760         return dot(A, dot(B, C), out=out)
#    2761
#    2762
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
